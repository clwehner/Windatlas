# %%
import boto3
 
access_key='ONRWEDLCOWQTIBKPLCMG'
secret_key='andIwnScwdDwExUKZqgfLmVXDJSaPVvMRYKILGKO'
 
host='http://data.cloud.code-de.org'
s3=boto3.client('s3',aws_access_key_id=access_key, aws_secret_access_key=secret_key, endpoint_url=host,)
for i in s3.list_objects(Delimiter='/', Bucket="CODEDE", Prefix='Sentinel-2/MSI/L1C/2020/04/28/',MaxKeys=30000)['CommonPrefixes']:
        print(i)
# Out:
# {'Prefix': 'Sentinel-2/MSI/L1C/2020/04/28/S2A_MSIL1C_20200428T101031_N0209_R022_T32TNS_20200428T111417.SAFE/'}
# {'Prefix': 'Sentinel-2/MSI/L1C/2020/04/28/S2A_MSIL1C_20200428T101031_N0209_R022_T32TNT_20200428T111417.SAFE/'}
# {'Prefix': 'Sentinel-2/MSI/L1C/2020/04/28/S2A_MSIL1C_20200428T101031_N0209_R022_T32TPS_20200428T111417.SAFE/'}
# {'Prefix': 'Sentinel-2/MSI/L1C/2020/04/28/S2A_MSIL1C_20200428T101031_N0209_R022_T32TPT_20200428T111417.SAFE/'}
# {'Prefix': 'Sentinel-2/MSI/L1C/2020/04/28/S2A_MSIL1C_20200428T101031_N0209_R022_T32TQS_20200428T111417.SAFE/'}
# {'Prefix': 'Sentinel-2/MSI/L1C/2020/04/28/S2A_MSIL1C_20200428T101031_N0209_R022_T32TQT_20200428T111417.SAFE/'}
# {'Prefix': 'Sentinel-2/MSI/L1C/2020/04/28/S2A_MSIL1C_20200428T101031_N0209_R022_T32UPA_20200428T111417.SAFE/'}
# {'Prefix': 'Sentinel-2/MSI/L1C/2020/04/28/S2A_MSIL1C_20200428T101031_N0209_R022_T32UPB_20200428T111417.SAFE/'}
# ...
